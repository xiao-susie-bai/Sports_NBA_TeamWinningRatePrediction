# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np
import pandas as pd

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# !pip install linearmodels
from linearmodels import PanelOLS
# Out:
# Requirement already satisfied: linearmodels in /anaconda3/lib/python3.7/site-packages (4.17)
# Requirement already satisfied: numpy>=1.15 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (1.18.1)
# Requirement already satisfied: Cython>=0.29.14 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (0.29.15)
# Requirement already satisfied: scipy>=1 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (1.4.1)
# Requirement already satisfied: mypy-extensions>=0.4 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: statsmodels>=0.9 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (0.11.0)
# Requirement already satisfied: patsy in /anaconda3/lib/python3.7/site-packages (from linearmodels) (0.5.1)
# Requirement already satisfied: property-cached>=1.6.3 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: pandas>=0.23 in /anaconda3/lib/python3.7/site-packages (from linearmodels) (1.0.1)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from patsy->linearmodels) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /anaconda3/lib/python3.7/site-packages (from pandas>=0.23->linearmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /anaconda3/lib/python3.7/site-packages (from pandas>=0.23->linearmodels) (2019.3)

# %% [markdown]
# # Import Datasets

# %%
data_a=pd.read_csv("/Users/baixiao/Desktop/sports/data 2001-2019.csv")

# %%
data_a.head()
# Out:
#    Year   Tm        Player Pos  Age   G   MP   PER    TS.  X3PAr  ...  TRB  \
# 0  2001  ATL  Pepe Sanchez  PG   23   5   34  -4.8  0.000  0.000  ...    1
# 1  2001  ATL    Toni Kukoc  SF   32  17  618  21.8  0.590  0.313  ...   97
# 2  2001  ATL   Jim Jackson  SF   30  17  550  12.7  0.478  0.175  ...   79
# 3  2001  ATL   Sean Colson  PG   25   3   14 -10.6  0.000  0.200  ...    3
# 4  2001  ATL    Tony Smith  SG   32   6   78   3.8  0.356  0.087  ...    3
#
#    AST  STL  BLK  TOV  PF  PTS  winning PCT  league rank  conference
# 0    5    2    0    3   3    0        0.305           25           E
# 1  106   13    5   51  36  335        0.305           25           E
# 2   50   19    4   48  42  243        0.305           25           E
# 3    3    0    0    2   0    0        0.305           25           E
# 4   10    7    0    9  12   17        0.305           25           E
#
# [5 rows x 52 columns]

# %%
data_a_pre=data_a[(data_a.Year==2019)]

# %%
data_a=data_a.drop(data_a[(data_a.Year==2019)].index)

# %%
data_a_pre
# Out:
#        Year   Tm            Player Pos  Age   G    MP   PER    TS.  X3PAr  \
# 9390   2019  ATL     Deyonta Davis   C   22   9   118  15.6  0.682  0.045
# 9391   2019  ATL    Omari Spellman  PF   21  46   805  12.4  0.516  0.525
# 9392   2019  ATL      Vince Carter  SF   42  76  1330  11.8  0.565  0.675
# 9393   2019  ATL      B.J. Johnson  SF   23   6    43  14.0  0.622  0.375
# 9394   2019  ATL   DeAndre' Bembry  SG   24  82  1931  10.8  0.508  0.281
# ...     ...  ...               ...  ..  ...  ..   ...   ...    ...    ...
# 10007  2019  WAS       Otto Porter  SF   25  41  1191  15.0  0.551  0.398
# 10008  2019  WAS        Jeff Green  PF   32  77  2097  13.6  0.608  0.466
# 10009  2019  WAS         Ron Baker  SG   25   4    45  -2.0  0.000  1.000
# 10010  2019  WAS     Austin Rivers  SG   26  29   683   6.8  0.490  0.546
# 10011  2019  WAS  Tomáš Satoranský  PG   27  80  2164  14.1  0.590  0.306
#
#        ...  TRB  AST  STL  BLK  TOV   PF  PTS  winning PCT  league rank  \
# 9390   ...   36    5    3    5    3   12   36        0.354           26
# 9391   ...  194   47   26   25   31   67  272        0.354           26
# 9392   ...  194   87   44   27   48  141  562        0.354           26
# 9393   ...    8    0    2    0    2    3   21        0.354           26
# 9394   ...  358  202  105   41  142  190  687        0.354           26
# ...    ...  ...  ...  ...  ...  ...  ...  ...          ...          ...
# 10007  ...  231   80   64   22   40   79  518        0.390           25
# 10008  ...  309  137   43   39  101  160  946        0.390           25
# 10009  ...    4    2    1    1    2    2    0        0.390           25
# 10010  ...   71   58   18   10   36   72  210        0.390           25
# 10011  ...  279  399   82   13  120  172  709        0.390           25
#
#        conference
# 9390            E
# 9391            E
# 9392            E
# 9393            E
# 9394            E
# ...           ...
# 10007           E
# 10008           E
# 10009           E
# 10010           E
# 10011           E
#
# [622 rows x 52 columns]

# %%
data_a.columns
# Out:
# Index(['Year', 'Tm', 'Player', 'Pos', 'Age', 'G', 'MP', 'PER', 'TS.', 'X3PAr',
#        'FTr', 'ORB.', 'DRB.', 'TRB.', 'AST.', 'STL.', 'BLK.', 'TOV.', 'USG.',
#        'OWS', 'DWS', 'WS', 'WS.48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA',
#        'FG.', 'X3P', 'X3PA', 'X3P.', 'X2P', 'X2PA', 'X2P.', 'eFG.', 'FT',
#        'FTA', 'FT.', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'winning PCT', 'league rank', 'conference'],
#       dtype='object')

# %%
data_a=data_a.drop(['league rank','Player'], axis=1)
data_a_pre=data_a_pre.drop(['league rank','Player'], axis=1)

# %%
# Change year_month column to datetime
#data_a['DATE'] = pd.to_datetime(data_a['year_month'], format="%Y-%m")

# %% [markdown]
# ### Optional - Lagged Sales

# %%
#data_a["Sales_Lag"] = data_a['TOTAL_SALES_AMT']

# %% [markdown]
# # EDA

# %%
data_a.head()
# Out:
#    Year   Tm Pos  Age   G   MP   PER    TS.  X3PAr    FTr  ...  DRB  TRB  AST  \
# 0  2001  ATL  PG   23   5   34  -4.8  0.000  0.000  0.000  ...    0    1    5
# 1  2001  ATL  SF   32  17  618  21.8  0.590  0.313  0.286  ...   78   97  106
# 2  2001  ATL  SF   30  17  550  12.7  0.478  0.175  0.392  ...   62   79   50
# 3  2001  ATL  PG   25   3   14 -10.6  0.000  0.200  0.000  ...    3    3    3
# 4  2001  ATL  SG   32   6   78   3.8  0.356  0.087  0.087  ...    1    3   10
#
#    STL  BLK  TOV  PF  PTS  winning PCT  conference
# 0    2    0    3   3    0        0.305           E
# 1   13    5   51  36  335        0.305           E
# 2   19    4   48  42  243        0.305           E
# 3    0    0    2   0    0        0.305           E
# 4    7    0    9  12   17        0.305           E
#
# [5 rows x 50 columns]

# %%
# Change the DATE from object to Datetime
data_a['Year'] = pd.to_datetime(data_a['Year'], format="%Y")
data_a_pre['Year'] = pd.to_datetime(data_a_pre['Year'], format="%Y")

# %%
# Check null values 
data_a.isnull().sum()
# Out:
# Year           0
# Tm             0
# Pos            0
# Age            0
# G              0
# MP             0
# PER            0
# TS.            0
# X3PAr          0
# FTr            0
# ORB.           0
# DRB.           0
# TRB.           0
# AST.           0
# STL.           0
# BLK.           0
# TOV.           0
# USG.           0
# OWS            0
# DWS            0
# WS             0
# WS.48          0
# OBPM           0
# DBPM           0
# BPM            0
# VORP           0
# FG             0
# FGA            0
# FG.            0
# X3P            0
# X3PA           0
# X3P.           0
# X2P            0
# X2PA           0
# X2P.           0
# eFG.           0
# FT             0
# FTA            0
# FT.            0
# ORB            0
# DRB            0
# TRB            0
# AST            0
# STL            0
# BLK            0
# TOV            0
# PF             0
# PTS            0
# winning PCT    0
# conference     0
# dtype: int64

# %%
data_a.shape
# Out:
# (9390, 50)

# %%
data_a.dtypes
# Out:
# Year           datetime64[ns]
# Tm                     object
# Pos                    object
# Age                     int64
# G                       int64
# MP                      int64
# PER                   float64
# TS.                   float64
# X3PAr                 float64
# FTr                   float64
# ORB.                  float64
# DRB.                  float64
# TRB.                  float64
# AST.                  float64
# STL.                  float64
# BLK.                  float64
# TOV.                  float64
# USG.                  float64
# OWS                   float64
# DWS                   float64
# WS                    float64
# WS.48                 float64
# OBPM                  float64
# DBPM                  float64
# BPM                   float64
# VORP                  float64
# FG                      int64
# FGA                     int64
# FG.                   float64
# X3P                     int64
# X3PA                    int64
# X3P.                  float64
# X2P                     int64
# X2PA                    int64
# X2P.                  float64
# eFG.                  float64
# FT                      int64
# FTA                     int64
# FT.                   float64
# ORB                     int64
# DRB                     int64
# TRB                     int64
# AST                     int64
# STL                     int64
# BLK                     int64
# TOV                     int64
# PF                      int64
# PTS                     int64
# winning PCT           float64
# conference             object
# dtype: object

# %%
data_a=pd.get_dummies(data_a, columns=['Pos'])
data_a_pre=pd.get_dummies(data_a_pre, columns=['Pos'])

# %%
data_a=pd.get_dummies(data_a, columns=['conference'])
data_a_pre=pd.get_dummies(data_a_pre, columns=['conference'])

# %%
#remove extra dummies
data_a=data_a.drop(['conference_E','Pos_SG'], axis=1)
data_a_pre=data_a_pre.drop(['conference_E','Pos_SG'], axis=1)

# %%
data_a[['MP']].mean()
# Out:
# MP    1119.502023
# dtype: float64

# %%
#check mp
import matplotlib.pyplot as plt

#x = [value1, value2, value3,....]
plt.hist(data_a['MP'], bins =20)
plt.show()

# %%
data_a.shape
# Out:
# (9390, 53)

# %%
#remove player that has low MP
data_a1 = data_a.drop(data_a[(data_a.MP < 400)].index)
data_a1_pre = data_a_pre.drop(data_a_pre[(data_a_pre.MP < 400)].index)
data_a1.shape
# Out:
# (6565, 53)

# %%
# Sort the datasets by team and date
df = data_a1
df_pre=data_a1_pre
df.sort_values(["Tm", "Year"],inplace=True)
df_pre.sort_values(["Tm", "Year"],inplace=True)
# Set date and team as two indexs for the panel ols
df = df.set_index(["Tm", "Year"])
df_pre = df_pre.set_index(["Tm", "Year"])
df
# Out:
#                 Age   G    MP   PER    TS.  X3PAr    FTr  ORB.  DRB.  TRB.  \
# Tm  Year
# ATL 2001-01-01   32  17   618  21.8  0.590  0.313  0.286   3.4  14.2   8.7
#     2001-01-01   30  17   550  12.7  0.478  0.175  0.392   3.4  12.6   8.0
#     2001-01-01   25  47  1364  12.9  0.424  0.028  0.169   1.8  11.4   6.6
#     2001-01-01   20  78  1313   8.4  0.463  0.326  0.223   4.7  10.4   7.6
#     2001-01-01   28  73  1810  14.0  0.487  0.001  0.404  11.0  14.0  12.5
# ...             ...  ..   ...   ...    ...    ...    ...   ...   ...   ...
# WAS 2018-01-01   26  73  1643  15.4  0.615  0.263  0.250   5.0  11.1   8.0
#     2018-01-01   33  82  2075  14.7  0.546  0.000  0.291   9.9  24.0  17.0
#     2018-01-01   24  82  2977  18.4  0.564  0.357  0.249   2.3  11.5   6.9
#     2018-01-01   28  73  1968  13.2  0.566  0.301  0.186   4.3  19.2  11.8
#     2018-01-01   27  59   838  11.3  0.475  0.326  0.174   2.4  13.1   7.8
#
#                 ...  BLK  TOV   PF   PTS  winning PCT  Pos_C  Pos_PF  Pos_PG  \
# Tm  Year        ...
# ATL 2001-01-01  ...    5   51   36   335        0.305      0       0       0
#     2001-01-01  ...    4   48   42   243        0.305      0       0       0
#     2001-01-01  ...    3   84  138   324        0.305      0       0       1
#     2001-01-01  ...   30   93  134   397        0.305      0       0       0
#     2001-01-01  ...   29  126  164   769        0.305      0       1       0
# ...             ...  ...  ...  ...   ...          ...    ...     ...     ...
# WAS 2018-01-01  ...   15   83  131   524        0.511      0       0       0
#     2018-01-01  ...   61   99  175   690        0.511      1       0       0
#     2018-01-01  ...   36  214  160  1857        0.511      0       0       0
#     2018-01-01  ...   38  127  216   841        0.511      0       1       0
#     2018-01-01  ...    7   57   97   176        0.511      0       0       1
#
#                 Pos_SF  conference_W
# Tm  Year
# ATL 2001-01-01       1             0
#     2001-01-01       1             0
#     2001-01-01       0             0
#     2001-01-01       1             0
#     2001-01-01       0             0
# ...                ...           ...
# WAS 2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#
# [6565 rows x 51 columns]

# %%
df.columns.values
# Out:
# array(['Age', 'G', 'MP', 'PER', 'TS.', 'X3PAr', 'FTr', 'ORB.', 'DRB.',
#        'TRB.', 'AST.', 'STL.', 'BLK.', 'TOV.', 'USG.', 'OWS', 'DWS', 'WS',
#        'WS.48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG.', 'X3P',
#        'X3PA', 'X3P.', 'X2P', 'X2PA', 'X2P.', 'eFG.', 'FT', 'FTA', 'FT.',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'winning PCT', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF',
#        'conference_W'], dtype=object)

# %%
df = df.fillna(0)
df_pre = df_pre.fillna(0)

# %% [markdown]
# # Feature Engineering

# %%
#correlation matrix for words
corrmat = df[['Age', 'G', 'MP', 'PER', 'TS.', 'X3PAr', 'FTr', 'ORB.', 'DRB.',
       'TRB.', 'AST.', 'STL.', 'BLK.', 'TOV.', 'USG.', 'OWS', 'DWS', 'WS',
       'WS.48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG.', 'X3P',
       'X3PA', 'X3P.', 'X2P', 'X2PA', 'X2P.', 'eFG.', 'FT', 'FTA', 'FT.',
       'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
       'winning PCT', 'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF',
       'conference_W']].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
# log transformation
#df['XX_log']=np.log(df['XX'])

# %%
df.dtypes
# Out:
# Age               int64
# G                 int64
# MP                int64
# PER             float64
# TS.             float64
# X3PAr           float64
# FTr             float64
# ORB.            float64
# DRB.            float64
# TRB.            float64
# AST.            float64
# STL.            float64
# BLK.            float64
# TOV.            float64
# USG.            float64
# OWS             float64
# DWS             float64
# WS              float64
# WS.48           float64
# OBPM            float64
# DBPM            float64
# BPM             float64
# VORP            float64
# FG                int64
# FGA               int64
# FG.             float64
# X3P               int64
# X3PA              int64
# X3P.            float64
# X2P               int64
# X2PA              int64
# X2P.            float64
# eFG.            float64
# FT                int64
# FTA               int64
# FT.             float64
# ORB               int64
# DRB               int64
# TRB               int64
# AST               int64
# STL               int64
# BLK               int64
# TOV               int64
# PF                int64
# PTS               int64
# winning PCT     float64
# Pos_C             uint8
# Pos_PF            uint8
# Pos_PG            uint8
# Pos_SF            uint8
# conference_W      uint8
# dtype: object

# %% [markdown]
# # Panel

# %%
df_pn = df
df_pn_pre = df_pre
df_pn.head()
# Out:
#                 Age   G    MP   PER    TS.  X3PAr    FTr  ORB.  DRB.  TRB.  \
# Tm  Year
# ATL 2001-01-01   32  17   618  21.8  0.590  0.313  0.286   3.4  14.2   8.7
#     2001-01-01   30  17   550  12.7  0.478  0.175  0.392   3.4  12.6   8.0
#     2001-01-01   25  47  1364  12.9  0.424  0.028  0.169   1.8  11.4   6.6
#     2001-01-01   20  78  1313   8.4  0.463  0.326  0.223   4.7  10.4   7.6
#     2001-01-01   28  73  1810  14.0  0.487  0.001  0.404  11.0  14.0  12.5
#
#                 ...  BLK  TOV   PF  PTS  winning PCT  Pos_C  Pos_PF  Pos_PG  \
# Tm  Year        ...
# ATL 2001-01-01  ...    5   51   36  335        0.305      0       0       0
#     2001-01-01  ...    4   48   42  243        0.305      0       0       0
#     2001-01-01  ...    3   84  138  324        0.305      0       0       1
#     2001-01-01  ...   30   93  134  397        0.305      0       0       0
#     2001-01-01  ...   29  126  164  769        0.305      0       1       0
#
#                 Pos_SF  conference_W
# Tm  Year
# ATL 2001-01-01       1             0
#     2001-01-01       1             0
#     2001-01-01       0             0
#     2001-01-01       1             0
#     2001-01-01       0             0
#
# [5 rows x 51 columns]

# %%
pd.set_option('display.max_rows', 100)
df
# Out:
#                 Age   G    MP   PER    TS.  X3PAr    FTr  ORB.  DRB.  TRB.  \
# Tm  Year
# ATL 2001-01-01   32  17   618  21.8  0.590  0.313  0.286   3.4  14.2   8.7
#     2001-01-01   30  17   550  12.7  0.478  0.175  0.392   3.4  12.6   8.0
#     2001-01-01   25  47  1364  12.9  0.424  0.028  0.169   1.8  11.4   6.6
#     2001-01-01   20  78  1313   8.4  0.463  0.326  0.223   4.7  10.4   7.6
#     2001-01-01   28  73  1810  14.0  0.487  0.001  0.404  11.0  14.0  12.5
# ...             ...  ..   ...   ...    ...    ...    ...   ...   ...   ...
# WAS 2018-01-01   26  73  1643  15.4  0.615  0.263  0.250   5.0  11.1   8.0
#     2018-01-01   33  82  2075  14.7  0.546  0.000  0.291   9.9  24.0  17.0
#     2018-01-01   24  82  2977  18.4  0.564  0.357  0.249   2.3  11.5   6.9
#     2018-01-01   28  73  1968  13.2  0.566  0.301  0.186   4.3  19.2  11.8
#     2018-01-01   27  59   838  11.3  0.475  0.326  0.174   2.4  13.1   7.8
#
#                 ...  BLK  TOV   PF   PTS  winning PCT  Pos_C  Pos_PF  Pos_PG  \
# Tm  Year        ...
# ATL 2001-01-01  ...    5   51   36   335        0.305      0       0       0
#     2001-01-01  ...    4   48   42   243        0.305      0       0       0
#     2001-01-01  ...    3   84  138   324        0.305      0       0       1
#     2001-01-01  ...   30   93  134   397        0.305      0       0       0
#     2001-01-01  ...   29  126  164   769        0.305      0       1       0
# ...             ...  ...  ...  ...   ...          ...    ...     ...     ...
# WAS 2018-01-01  ...   15   83  131   524        0.511      0       0       0
#     2018-01-01  ...   61   99  175   690        0.511      1       0       0
#     2018-01-01  ...   36  214  160  1857        0.511      0       0       0
#     2018-01-01  ...   38  127  216   841        0.511      0       1       0
#     2018-01-01  ...    7   57   97   176        0.511      0       0       1
#
#                 Pos_SF  conference_W
# Tm  Year
# ATL 2001-01-01       1             0
#     2001-01-01       1             0
#     2001-01-01       0             0
#     2001-01-01       1             0
#     2001-01-01       0             0
# ...                ...           ...
# WAS 2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#     2018-01-01       0             0
#
# [6565 rows x 51 columns]

# %%
#correlation matrix for words
corrmat = df[['Age', 'G','PER','X3PAr', 'FTr', 'USG.','DWS',
       'OBPM', 'DBPM','FG', 'FG.', 'X3P',
       'ORB', 'AST', 'STL', 'BLK','PF',
       'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF',
       'conference_W']].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
# Set X and Y varibales
X=df_pn[['Age', 'G','PER','X3PAr', 'FTr', 'USG.','DWS',
       'OBPM', 'DBPM','FG', 'FG.', 'X3P',
       'ORB', 'AST', 'STL', 'BLK','PF',
       'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF',
       'conference_W']]
X_pre=df_pn_pre[['Age', 'G','PER','X3PAr', 'FTr', 'USG.','DWS',
       'OBPM', 'DBPM','FG', 'FG.', 'X3P',
       'ORB', 'AST', 'STL', 'BLK','PF',
       'Pos_C', 'Pos_PF', 'Pos_PG', 'Pos_SF',
       'conference_W']]

y=df_pn['winning PCT']

y1=np.log(y)

# %%
import statsmodels.api as sm
X=sm.add_constant(X)

# %%
# Fit the PanelOLS model
mod = PanelOLS(y,X, entity_effects=True,time_effects=True)
res = mod.fit(cov_type='clustered', cluster_entity=True)
res
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            winning PCT   R-squared:                        0.4010
# Estimator:                   PanelOLS   R-squared (Between):              0.1259
# No. Observations:                6565   R-squared (Within):               0.3971
# Date:                Tue, Aug 11 2020   R-squared (Overall):              0.3218
# Time:                        22:15:32   Log-likelihood                    5692.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      197.42
# Entities:                          37   P-value                           0.0000
# Avg Obs:                       177.43   Distribution:                 F(22,6489)
# Min Obs:                       13.000
# Max Obs:                       232.00   F-statistic (robust):             57.181
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                 F(22,6489)
# Avg Obs:                       364.72
# Min Obs:                       341.00
# Max Obs:                       405.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            0.3646     0.0605     6.0255     0.0000      0.2460      0.4832
# Age              0.0027     0.0004     6.0675     0.0000      0.0018      0.0036
# G                0.0025     0.0003     10.054     0.0000      0.0020      0.0030
# PER             -0.0158     0.0020    -8.0292     0.0000     -0.0196     -0.0119
# X3PAr           -0.0576     0.0329    -1.7531     0.0796     -0.1221      0.0068
# FTr             -0.0065     0.0156    -0.4154     0.6779     -0.0371      0.0241
# USG.             0.0057     0.0009     6.1485     0.0000      0.0039      0.0075
# DWS              0.1072     0.0073     14.667     0.0000      0.0929      0.1215
# OBPM             0.0360     0.0043     8.3612     0.0000      0.0276      0.0445
# DBPM             0.0150     0.0033     4.4943     0.0000      0.0085      0.0216
# FG              -0.0002  3.551e-05    -4.6647     0.0000     -0.0002  -9.602e-05
# FG.              0.4102     0.0718     5.7090     0.0000      0.2693      0.5510
# X3P             -0.0002  7.401e-05    -3.0604     0.0022     -0.0004  -8.141e-05
# ORB             -0.0006  6.808e-05    -8.8709     0.0000     -0.0007     -0.0005
# AST             -0.0001  2.129e-05    -6.2397     0.0000     -0.0002  -9.112e-05
# STL             -0.0017     0.0002    -9.7748     0.0000     -0.0020     -0.0013
# BLK             -0.0008     0.0001    -5.9019     0.0000     -0.0011     -0.0006
# PF              -0.0005  6.797e-05    -7.0649     0.0000     -0.0006     -0.0003
# Pos_C            0.0073     0.0066     1.0930     0.2744     -0.0058      0.0203
# Pos_PF           0.0007     0.0061     0.1088     0.9134     -0.0114      0.0127
# Pos_PG           0.0166     0.0054     3.0939     0.0020      0.0061      0.0271
# Pos_SF          -0.0119     0.0043    -2.7405     0.0062     -0.0204     -0.0034
# conference_W    -0.0630     0.0178    -3.5336     0.0004     -0.0980     -0.0280
# ================================================================================
#
# F-test for Poolability: 12.814
# P-value: 0.0000
# Distribution: F(53,6489)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x7fd8214d79d0
